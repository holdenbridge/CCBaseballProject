# %% [markdown]
# # Centennial Conference Offensive Statistics
#
# By: Holden Bridge

# %%
# import libraries 

from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
from tkinter import *

import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as mpatches
import numpy as np 
from pylab import rcParams

plt.rcParams["figure.figsize"] = (25,12.5)

df = pd.read_excel(r'CCBaseball.xlsx')

# %%
# Remove unnecessay columns

df1= df.drop(columns = ['Unnamed: 24', 'Unnamed: 26', 'Unnamed: 28', 'Unnamed: 30', 'Unnamed: 32', 'Unnamed: 34', 'Unnamed: 36', 'Unnamed: 38', 'Unnamed: 40', 'Unnamed: 42', 'WOBAScale', 'lgwSB'])

CCdict = df1.to_dict(orient = 'index')

# %%
# Batting Average Histogram 

fig, ax = plt.subplots()

ax.set_xlim(.18, .4)
ax.set_ylim(0, 15)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (0.385, 13.1))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['AVG'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['AVG'].mean(), color = 'red')
plt.axvline(x=df1['AVG'].median(), color = 'blue')
plt.xlabel("Batting Average", size = 20)
plt.title("Centennial Conference Batting Average Histogram", size = 27)

MEAN = mpatches.Patch(color='red', label='Mean')
MED = mpatches.Patch(color='blue', label='Median')
plt.legend(handles=[MEAN, MED], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 40})

plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Conference Batting Average Visualization

#testing 
fig, ax = plt.subplots()

ax.set_xlim(.18, .4)
ax.set_ylim(0, 15)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (0.385, 13.1))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['AVG'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['AVG'].mean(), color = 'red')
plt.axvline(x=df1['AVG'].median(), color = 'blue')
plt.xlabel("Batting Average", size = 20)
plt.title("Centennial Conference Batting Average", size = 27)


for player in CCdict.keys():
    if (df1.loc[player]['Team'] == 'SWAT'):
        plt.plot(df1.loc[player]['AVG'], 7.5, marker= '*', markersize= 25, color = 'maroon', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'JHU'):
        plt.plot(df1.loc[player]['AVG'], 5.5, marker= '*', markersize= 25, color = 'skyblue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'F&M'):
        plt.plot(df1.loc[player]['AVG'], 4.5, marker= '*', markersize= 25, color = 'blue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'URS'):
        plt.plot(df1.loc[player]['AVG'], 6.5, marker= '*', markersize= 25, color = 'yellow', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'HAV'):
        plt.plot(df1.loc[player]['AVG'], 3.5, marker= '*', markersize= 25, color = 'black', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MCD'):
        plt.plot(df1.loc[player]['AVG'], 8.5, marker= '*', markersize= 25, color = 'green', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'GET'):
        plt.plot(df1.loc[player]['AVG'], 9.5, marker= '*', markersize= 25, color = 'orange', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'WAC'):
        plt.plot(df1.loc[player]['AVG'], 0.5, marker= '*', markersize= 25, color = 'goldenrod', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MUH'):
        plt.plot(df1.loc[player]['AVG'], 1.5, marker= '*', markersize= 25, color = 'white', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'DKN'):
        plt.plot(df1.loc[player]['AVG'], 2.5, marker= '*', markersize= 25, color = 'red', markeredgecolor= 'black')
        
DKN = mpatches.Patch(color='red', label='Dickinson- .282')
MUH = mpatches.Patch(color='white', label='Muhlenburg- .278')
WAC = mpatches.Patch(color='goldenrod', label='Washington College- .274')
GET = mpatches.Patch(color='orange', label='Gettysburg- .322')
MCD = mpatches.Patch(color='green', label='McDaniel- .312')
HAV = mpatches.Patch(color='black', label='Haverford- .289')
URS = mpatches.Patch(color='yellow', label='Ursinus- .308')
FM = mpatches.Patch(color='blue', label='Franklin & Marshall- .295')
JHU = mpatches.Patch(color='skyblue', label='Johns Hopkins- .295')
SWA = mpatches.Patch(color='maroon', label='Swarthmore- .310')
plt.legend(handles=[GET, MCD, SWA, URS, JHU, FM, HAV, DKN, MUH, WAC], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 17.5})


# plt.savefig("AVG Histogram with Stars")
plt.show()

# %%
# OPS Histogram 

fig, ax = plt.subplots()

ax.set_xlim(.45, 1.2)
ax.set_ylim(0, 19)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (1.15, 16.5))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['OPS'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['OPS'].mean(), color = 'red')
plt.axvline(x=df1['OPS'].median(), color = 'blue')
plt.xlabel("OPS", size = 20)
plt.title("Centennial Conference OPS Histogram", size = 27)

MEAN = mpatches.Patch(color='red', label='Mean')
MED = mpatches.Patch(color='blue', label='Median')
plt.legend(handles=[MEAN, MED], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 40})

# plt.savefig("OPS Histogram")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Conference OPS Visualization

fig, ax = plt.subplots()

ax.set_xlim(.45, 1.2)
ax.set_ylim(0, 19)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (1.15, 16.5))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['OPS'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['OPS'].mean(), color = 'red')
plt.axvline(x=df1['OPS'].median(), color = 'blue')
plt.xlabel("OPS", size = 20)
plt.title("Centennial Conference OPS", size = 27)


for player in CCdict.keys():
    if (df1.loc[player]['Team'] == 'SWAT'):
        plt.plot(df1.loc[player]['OPS'], 6.5, marker= '*', markersize= 25, color = 'maroon', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'JHU'):
        plt.plot(df1.loc[player]['OPS'], 9.5, marker= '*', markersize= 25, color = 'skyblue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'F&M'):
        plt.plot(df1.loc[player]['OPS'], 3.5, marker= '*', markersize= 25, color = 'blue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'URS'):
        plt.plot(df1.loc[player]['OPS'], 7.5, marker= '*', markersize= 25, color = 'yellow', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'HAV'):
        plt.plot(df1.loc[player]['OPS'], 5.5, marker= '*', markersize= 25, color = 'black', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MCD'):
        plt.plot(df1.loc[player]['OPS'], 4.5, marker= '*', markersize= 25, color = 'green', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'GET'):
        plt.plot(df1.loc[player]['OPS'], 8.5, marker= '*', markersize= 25, color = 'orange', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'WAC'):
        plt.plot(df1.loc[player]['OPS'], 1.5, marker= '*', markersize= 25, color = 'goldenrod', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MUH'):
        plt.plot(df1.loc[player]['OPS'], 0.5, marker= '*', markersize= 25, color = 'white', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'DKN'):
        plt.plot(df1.loc[player]['OPS'], 2.5, marker= '*', markersize= 25, color = 'red', markeredgecolor= 'black')
        
DKN = mpatches.Patch(color='red', label='Dickinson- .748')
MUH = mpatches.Patch(color='white', label='Muhlenburg- .730')
WAC = mpatches.Patch(color='goldenrod', label='Washington College- .747')
GET = mpatches.Patch(color='orange', label='Gettysburg- .830')
MCD = mpatches.Patch(color='green', label='McDaniel- .789')
HAV = mpatches.Patch(color='black', label='Haverford- .790')
URS = mpatches.Patch(color='yellow', label='Ursinus- .821')
FM = mpatches.Patch(color='blue', label='Franklin & Marshall- .776')
JHU = mpatches.Patch(color='skyblue', label='Johns Hopkins- .866')
SWA = mpatches.Patch(color='maroon', label='Swarthmore- .812')
plt.legend(handles=[JHU, GET, URS, SWA, HAV, MCD, FM, DKN, WAC, MUH], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 17.5})


plt.savefig("OPS Histogram with Stars")
plt.show()

# %%
# wOBA Histogram 

fig, ax = plt.subplots()

ax.set_xlim(.23, .5)
ax.set_ylim(0, 20)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (0.483, 17.5))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['wOBA'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['wOBA'].mean(), color = 'red')
plt.axvline(x=df1['wOBA'].median(), color = 'blue')
plt.xlabel("Weighted On-Base Average ", size = 20)
plt.title("Centennial Conference wOBA Histogram", size = 27)

MEAN = mpatches.Patch(color='red', label='Mean')
MED = mpatches.Patch(color='blue', label='Median')
plt.legend(handles=[MEAN, MED], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 40})

# plt.savefig("wOBA Histogram")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Conference wOBA Visualization

fig, ax = plt.subplots()

ax.set_xlim(.23, .5)
ax.set_ylim(0, 20)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (0.483, 17.5))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['wOBA'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['wOBA'].mean(), color = 'red')
plt.axvline(x=df1['wOBA'].median(), color = 'blue')
plt.xlabel("Weighted On-Base Average ", size = 20)
plt.title("Centennial Conference wOBA", size = 27)


for player in CCdict.keys():
    if (df1.loc[player]['Team'] == 'SWAT'):
        plt.plot(df1.loc[player]['wOBA'], 6.5, marker= '*', markersize= 25, color = 'maroon', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'JHU'):
        plt.plot(df1.loc[player]['wOBA'], 9.5, marker= '*', markersize= 25, color = 'skyblue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'F&M'):
        plt.plot(df1.loc[player]['wOBA'], 3.5, marker= '*', markersize= 25, color = 'blue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'URS'):
        plt.plot(df1.loc[player]['wOBA'], 7.5, marker= '*', markersize= 25, color = 'yellow', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'HAV'):
        plt.plot(df1.loc[player]['wOBA'], 5.5, marker= '*', markersize= 25, color = 'black', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MCD'):
        plt.plot(df1.loc[player]['wOBA'], 4.5, marker= '*', markersize= 25, color = 'green', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'GET'):
        plt.plot(df1.loc[player]['wOBA'], 8.5, marker= '*', markersize= 25, color = 'orange', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'WAC'):
        plt.plot(df1.loc[player]['wOBA'], 2.5, marker= '*', markersize= 25, color = 'goldenrod', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MUH'):
        plt.plot(df1.loc[player]['wOBA'], 0.5, marker= '*', markersize= 25, color = 'white', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'DKN'):
        plt.plot(df1.loc[player]['wOBA'], 1.5, marker= '*', markersize= 25, color = 'red', markeredgecolor= 'black')
        
DKN = mpatches.Patch(color='red', label='Dickinson- .331')
MUH = mpatches.Patch(color='white', label='Muhlenburg- .324')
WAC = mpatches.Patch(color='goldenrod', label='Washington College- .333')
GET = mpatches.Patch(color='orange', label='Gettysburg- .362')
MCD = mpatches.Patch(color='green', label='McDaniel- .346')
HAV = mpatches.Patch(color='black', label='Haverford- .348')
URS = mpatches.Patch(color='yellow', label='Ursinus- .360')
FM = mpatches.Patch(color='blue', label='Franklin & Marshall- .342')
JHU = mpatches.Patch(color='skyblue', label='Johns Hopkins- .375')
SWA = mpatches.Patch(color='maroon', label='Swarthmore- .357')
plt.legend(handles=[JHU, GET, URS, SWA, HAV, MCD, FM, WAC, DKN, MUH], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 17.5})


# plt.savefig("wOBA Histogram with Stars")
plt.show()

# %%
# ISO Histogram 

fig, ax = plt.subplots()

ax.set_xlim(-.03, .4)
ax.set_ylim(0,17)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (0.37, 14.8))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['ISO'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['ISO'].mean(), color = 'red')
plt.axvline(x=df1['ISO'].median(), color = 'blue')
plt.xlabel("ISO", size = 20)
plt.title("Centennial Conference Isolated Power", size = 27)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# Text(0.5, 1.0, 'Centennial Conference Isolated Power')

# %%
# Conference ISO Visualization

fig, ax = plt.subplots()

ax.set_xlim(-.05, .4)
ax.set_ylim(0,17)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (0.37, 14.8))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['ISO'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['ISO'].mean(), color = 'red')
plt.axvline(x=df1['ISO'].median(), color = 'blue')
plt.xlabel("ISO", size = 20)
plt.title("Centennial Conference Isolated Power", size = 27)


for player in CCdict.keys():
    if (df1.loc[player]['Team'] == 'SWAT'):
        plt.plot(df1.loc[player]['ISO'], 5.5, marker= '*', markersize= 25, color = 'maroon', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'JHU'):
        plt.plot(df1.loc[player]['ISO'], 9.5, marker= '*', markersize= 25, color = 'skyblue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'F&M'):
        plt.plot(df1.loc[player]['ISO'], 2.5, marker= '*', markersize= 25, color = 'blue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'URS'):
        plt.plot(df1.loc[player]['ISO'], 8.5, marker= '*', markersize= 25, color = 'yellow', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'HAV'):
        plt.plot(df1.loc[player]['ISO'], 7.5, marker= '*', markersize= 25, color = 'black', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MCD'):
        plt.plot(df1.loc[player]['ISO'], 3.5, marker= '*', markersize= 25, color = 'green', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'GET'):
        plt.plot(df1.loc[player]['ISO'], 6.5, marker= '*', markersize= 25, color = 'orange', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'WAC'):
        plt.plot(df1.loc[player]['ISO'], 4.5, marker= '*', markersize= 25, color = 'goldenrod', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MUH'):
        plt.plot(df1.loc[player]['ISO'], 0.5, marker= '*', markersize= 25, color = 'white', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'DKN'):
        plt.plot(df1.loc[player]['ISO'], 1.5, marker= '*', markersize= 25, color = 'red', markeredgecolor= 'black')
        
DKN = mpatches.Patch(color='red', label='Dickinson: .104')
MUH = mpatches.Patch(color='white', label='Muhlenburg: .099')
WAC = mpatches.Patch(color='goldenrod', label='Washington College: .108')
GET = mpatches.Patch(color='orange', label='Gettysburg: .123')
MCD = mpatches.Patch(color='green', label='McDaniel: .106')
HAV = mpatches.Patch(color='black', label='Haverford: .123')
URS = mpatches.Patch(color='yellow', label='Ursinus: .126')
FM = mpatches.Patch(color='blue', label='Franklin & Marshall: .104')
JHU = mpatches.Patch(color='skyblue', label='Johns Hopkins: .181')
SWA = mpatches.Patch(color='maroon', label='Swarthmore: .113')
plt.legend(handles=[JHU, URS, HAV, GET, SWA, WAC, MCD, FM, DKN, MUH], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 16.5})

plt.xticks(fontsize=16)

plt.savefig("ISO Histogram with Stars")
plt.show()

# %%
# K% Histogram 

fig, ax = plt.subplots()

ax.set_xlim(0, .35)
ax.set_ylim(0,17)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (0.325, 14.8))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['K%'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['K%'].mean(), color = 'red')
plt.axvline(x=df1['K%'].median(), color = 'blue')
plt.xlabel("Strikeout Percentage", size = 20)
plt.title("Centennial Conference Strikeout Percentage Histogram", size = 27)

MEAN = mpatches.Patch(color='red', label='Mean')
MED = mpatches.Patch(color='blue', label='Median')
plt.legend(handles=[MEAN, MED], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 35})

# plt.savefig("K% Histogram")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Conference Strikeout Percentage Visualization

fig, ax = plt.subplots()

ax.set_xlim(0, .35)
ax.set_ylim(0,17)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (0.325, 14.8))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['K%'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['K%'].mean(), color = 'red')
plt.axvline(x=df1['K%'].median(), color = 'blue')
plt.xlabel("Strikeout Percentage", size = 20)
plt.title("Centennial Conference Strikeout Percentage", size = 27)


for player in CCdict.keys():
    if (df1.loc[player]['Team'] == 'SWAT'):
        plt.plot(df1.loc[player]['K%'], 9.5, marker= '*', markersize= 25, color = 'maroon', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'JHU'):
        plt.plot(df1.loc[player]['K%'], 0.5, marker= '*', markersize= 25, color = 'skyblue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'F&M'):
        plt.plot(df1.loc[player]['K%'], 6.5, marker= '*', markersize= 25, color = 'blue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'URS'):
        plt.plot(df1.loc[player]['K%'], 4.5, marker= '*', markersize= 25, color = 'yellow', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'HAV'):
        plt.plot(df1.loc[player]['K%'], 3.5, marker= '*', markersize= 25, color = 'black', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MCD'):
        plt.plot(df1.loc[player]['K%'], 7.5, marker= '*', markersize= 25, color = 'green', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'GET'):
        plt.plot(df1.loc[player]['K%'], 8.5, marker= '*', markersize= 25, color = 'orange', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'WAC'):
        plt.plot(df1.loc[player]['K%'], 2.5, marker= '*', markersize= 25, color = 'goldenrod', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MUH'):
        plt.plot(df1.loc[player]['K%'], 5.5, marker= '*', markersize= 25, color = 'white', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'DKN'):
        plt.plot(df1.loc[player]['K%'], 1.5, marker= '*', markersize= 25, color = 'red', markeredgecolor= 'black')
        
DKN = mpatches.Patch(color='red', label='Dickinson: .167')
MUH = mpatches.Patch(color='white', label='Muhlenburg: .150')
WAC = mpatches.Patch(color='goldenrod', label='Washington College: .166')
GET = mpatches.Patch(color='orange', label='Gettysburg: .129')
MCD = mpatches.Patch(color='green', label='McDaniel: .138')
HAV = mpatches.Patch(color='black', label='Haverford: .159')
URS = mpatches.Patch(color='yellow', label='Ursinus: .157')
FM = mpatches.Patch(color='blue', label='Franklin & Marshall: .139')
JHU = mpatches.Patch(color='skyblue', label='Johns Hopkins: .168')
SWA = mpatches.Patch(color='maroon', label='Swarthmore: .128')
plt.legend(handles=[SWA, GET, MCD, FM, MUH, URS, HAV, WAC, DKN, JHU], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 16.5})


# plt.savefig("K% Histogram with Stars")
plt.show()

# %%
# wSB Histogram 

fig, ax = plt.subplots()

ax.set_xlim(-9, 9)
ax.set_ylim(0, 28)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (7.7, 24.5))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['wSB'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['wSB'].mean(), color = 'red')
plt.axvline(x=df1['wSB'].median(), color = 'blue')
plt.xlabel("Weighted Stolen Base Runs ", size = 20)
plt.title("Centennial Conference wSB Histogram", size = 27)

MEAN = mpatches.Patch(color='red', label='Mean')
MED = mpatches.Patch(color='blue', label='Median')
plt.legend(handles=[MEAN, MED], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 35})

# plt.savefig("wSB Histogram")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Conference wSB Visualization

fig, ax = plt.subplots()

ax.set_xlim(-9, 9)
ax.set_ylim(0, 28)

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.7)
ab = AnnotationBbox(imagebox, (7.7, 24.5))
ax.add_artist(ab)

# Histogram with Mean and Median Lines 
plt.hist(df1['wSB'], 24, edgecolor = 'black', color = 'gray')
plt.axvline(x=df1['wSB'].mean(), color = 'red')
plt.axvline(x=df1['wSB'].median(), color = 'blue')
plt.xlabel("Weighted Stolen Base Runs ", size = 20)
plt.title("Centennial Conference wSB", size = 27)


for player in CCdict.keys():
    if (df1.loc[player]['Team'] == 'SWAT'):
        plt.plot(df1.loc[player]['wSB'], 14.3, marker= '*', markersize= 25, color = 'maroon', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'JHU'):
        plt.plot(df1.loc[player]['wSB'], 8.3, marker= '*', markersize= 25, color = 'skyblue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'F&M'):
        plt.plot(df1.loc[player]['wSB'], 9.8, marker= '*', markersize= 25, color = 'blue', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'URS'):
        plt.plot(df1.loc[player]['wSB'], 0.8, marker= '*', markersize= 25, color = 'yellow', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'HAV'):
        plt.plot(df1.loc[player]['wSB'], 12.8, marker= '*', markersize= 25, color = 'black', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MCD'):
        plt.plot(df1.loc[player]['wSB'], 11.3, marker= '*', markersize= 25, color = 'green', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'GET'):
        plt.plot(df1.loc[player]['wSB'], 6.8, marker= '*', markersize= 25, color = 'orange', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'WAC'):
        plt.plot(df1.loc[player]['wSB'], 5.3, marker= '*', markersize= 25, color = 'goldenrod', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'MUH'):
        plt.plot(df1.loc[player]['wSB'], 3.8, marker= '*', markersize= 25, color = 'white', markeredgecolor= 'black')
    elif (df1.loc[player]['Team'] == 'DKN'):
        plt.plot(df1.loc[player]['wSB'], 2.3, marker= '*', markersize= 25, color = 'red', markeredgecolor= 'black')
        
DKN = mpatches.Patch(color='red', label='Dickinson: -0.726')
MUH = mpatches.Patch(color='white', label='Muhlenburg: -0.457')
WAC = mpatches.Patch(color='goldenrod', label='Washington College: -0.189')
GET = mpatches.Patch(color='orange', label='Gettysburg: -0.097')
MCD = mpatches.Patch(color='green', label='McDaniel: 0.470')
HAV = mpatches.Patch(color='black', label='Haverford: 1.058')
URS = mpatches.Patch(color='yellow', label='Ursinus: -1.173')
FM = mpatches.Patch(color='blue', label='Franklin & Marshall: -0.038')
JHU = mpatches.Patch(color='skyblue', label='Johns Hopkins: -0.087')
SWA = mpatches.Patch(color='maroon', label='Swarthmore: 1.214')
plt.legend(handles=[SWA, HAV, MCD, FM, JHU, GET, WAC, MUH, DKN, URS], loc = 'upper left', fancybox = True, shadow = True, facecolor = 'gainsboro', prop={'size': 17.5})


# plt.savefig("wSB Histogram with Stars")
plt.show()

# %%
df2 = {'Team': ['Swarthmore', 'Johns Hopkins', 'McDaniel', 'Gettysburg', 'Ursinus', 'Franklin & Marshall', 'Haverford', 'Washington College', 'Dickinson', 'Muhlenberg'], 
        'Runs': [.178, .177, .176, .173, .166, .162, .161, .161, .146, .129]}

# %%
# Conference r/PA Visualization

fig, ax = plt.subplots()

ax.set_xlim(-1, 10)
ax.set_ylim(0,.2)
ax.set_facecolor('gainsboro')

# Add Swarthmore Logo 
blockS = mpimg.imread('SwatS.png')
imagebox = OffsetImage(blockS, zoom=0.42)
ab = AnnotationBbox(imagebox, (0, .09))
ax.add_artist(ab)

hop = mpimg.imread('JHU.png')
imagebox = OffsetImage(hop, zoom=0.113)
ab = AnnotationBbox(imagebox, (1, .09))
ax.add_artist(ab)

mcd = mpimg.imread('MCD.png')
imagebox = OffsetImage(mcd, zoom=0.3)
ab = AnnotationBbox(imagebox, (2, .09))
ax.add_artist(ab)

get = mpimg.imread('GET.png')
imagebox = OffsetImage(get, zoom=0.35)
ab = AnnotationBbox(imagebox, (3, .09))
ax.add_artist(ab)

urs = mpimg.imread('URS.png')
imagebox = OffsetImage(urs, zoom=0.35)
ab = AnnotationBbox(imagebox, (4, .09))
ax.add_artist(ab)

fm = mpimg.imread('FM.png')
imagebox = OffsetImage(fm, zoom=0.38)
ab = AnnotationBbox(imagebox, (5, .09))
ax.add_artist(ab)

hav = mpimg.imread('HAV.png')
imagebox = OffsetImage(hav, zoom=0.35)
ab = AnnotationBbox(imagebox, (6, .09))
ax.add_artist(ab)

wac = mpimg.imread('WAC2.png')
imagebox = OffsetImage(wac, zoom=0.27)
ab = AnnotationBbox(imagebox, (7, .09))
ax.add_artist(ab)

dkn = mpimg.imread('DKN.png')
imagebox = OffsetImage(dkn, zoom=0.35)
ab = AnnotationBbox(imagebox, (8, .09))
ax.add_artist(ab)

muh = mpimg.imread('MUH.png')
imagebox = OffsetImage(muh, zoom=0.32)
ab = AnnotationBbox(imagebox, (9, .09))
ax.add_artist(ab)

barlist = plt.bar(df2['Team'], df2['Runs'], color= ['maroon', 'skyblue', 'green', 'orange', 'yellow', 'blue', 'black', 'goldenrod', 'red', 'white'], edgecolor = 'black', linewidth = 2)
# plt.xlabel("Runs per Plate Appearance", size = 20)
plt.title("Centennial Conference R / PA", size = 27)

plt.xticks(fontsize=16)
plt.yticks(fontsize=18)


plt.savefig("R-PA Bar Chart")

# %% [markdown]
# Please note that not all of the code is present. Also note that no functions are used, this code intended for use by the Swarthmore College Baseball coaching staff and is not designed to replicated or utilized by any other parties.
